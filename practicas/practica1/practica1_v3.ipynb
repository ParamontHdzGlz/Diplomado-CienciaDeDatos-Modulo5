# %% [markdown]
# # Manipulación, Exploración y Visualización de Datos

# %% [markdown]
# ## Preparación de ambiente

# %% [markdown]
# ### Carga de módulos

# %%
# Data Wrangling
import json as js
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# Data visualization
import cufflinks as cf
from sklearn.decomposition import PCA

# Preprocessing
from varclushi import VarClusHi
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif, f_regression

cf.go_offline()
pd.set_option("display.max_columns", 50)

import pymysql
pymysql.install_as_MySQLdb()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Funciones relevantes

# %%
def freq_discrete(df, features):
    for feature in features:
        print(f"Feature: {feature}")
        abs_ = df[feature].value_counts(dropna=False).to_frame().rename(columns={feature: "Absolute frequency"})
        rel_ = df[feature].value_counts(dropna=False, normalize= True).to_frame().rename(columns={feature: "Relative frequency"})
        freq = abs_.join(rel_)
        freq["Accumulated frequency"] = freq["Absolute frequency"].cumsum()
        freq["Accumulated %"] = freq["Relative frequency"].cumsum()
        freq["Absolute frequency"] = freq["Absolute frequency"].map(lambda x: "{:,.0f}".format(x))
        freq["Relative frequency"] = freq["Relative frequency"].map(lambda x: "{:,.2%}".format(x))
        freq["Accumulated frequency"] = freq["Accumulated frequency"].map(lambda x: "{:,.0f}".format(x))
        freq["Accumulated %"] = freq["Accumulated %"].map(lambda x: "{:,.2%}".format(x))
        display(freq)

# %%
def normalize(df, features):
    for feature in features:
        aux = df[feature].value_counts(True)
        ls_categories = [category for category, freq in aux.items() if freq > 0.05]
        df[feature] = df[feature].map(lambda x: x if x in ls_categories else "Others")
    return df

# %%
def get_bounds(x):
    q3 = x.quantile(0.75)
    q1 = x.quantile(0.25)
    iqr = q3 - q1
    lb = q1 - 1.5*iqr
    ub = q3 + 1.5*iqr
    return pd.Interval(lb, ub, closed="both")

# %% [markdown]
# ## Lectura de Datos

# %% [markdown]
# ### Lectura de credenciales

# %%
with open("cred.json", "r+") as file:
    cred = js.load(file)

# %%
db =  cred['db']
host =  cred['host']
port =  cred['port']
flavour = cred['flavour']
username = cred['username']
password = cred['password']

# %%
db
# Out:
# 'sakila'

# %% [markdown]
# ### Conexión con base de datos

# %%
conn = create_engine(f"{flavour}://{username}:{password}@{host}:{port}/{db}").connect()

# %% [markdown]
# ### Lectura de datos

# %%
df = pd.read_sql(con=conn, sql="""Select * 
                                    From film""")

# %%
df.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         0.99      86
# 1            1                 None                3         4.99      48
# 2            1                 None                7         2.99      50
# 3            1                 None                5         2.99     117
# 4            1                 None                6         2.99     130
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             12.99      G           Trailers,Deleted Scenes
# 2             18.99  NC-17           Trailers,Deleted Scenes
# 3             26.99      G    Commentaries,Behind the Scenes
# 4             22.99      G                    Deleted Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42
# 3 2006-02-15 05:03:42
# 4 2006-02-15 05:03:42

# %%
inventory = pd.read_sql(con = conn, sql = "inventory")
payment = pd.read_sql(con = conn, sql = "payment")
rental = pd.read_sql(con = conn, sql = "rental")


film_category = pd.read_sql(con = conn, sql = "film_category")
category = pd.read_sql(con = conn, sql = "category")
language = pd.read_sql(con = conn, sql = "language")
film_actor = pd.read_sql(con = conn, sql = "film_actor")

# %%
conn.close()

# %%
#merge with inventory
df = pd.merge(df, inventory, on='film_id',how='left')

# %%
#merge with rental
df = pd.merge(df, rental, on='inventory_id',how='left')

# %%
#merge with payment
df = pd.merge(df, payment, on='rental_id',how='left')

# %%
#merge with film_category
df = pd.merge(df, film_category, on='film_id',how='left')
#merge with film_category
df = pd.merge(df, category, on='category_id',how='left')

# %%
#merge with language
df = pd.merge(df, language, on='language_id',how='left')

# %%
#merge with film_actor
df = pd.merge(df, film_actor, on='film_id',how='left')

# %%
df.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        1  ACADEMY DINOSAUR
# 2        1  ACADEMY DINOSAUR
# 3        1  ACADEMY DINOSAUR
# 4        1  ACADEMY DINOSAUR
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 2  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 3  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         0.99      86
# 1            1                 None                6         0.99      86
# 2            1                 None                6         0.99      86
# 3            1                 None                6         0.99      86
# 4            1                 None                6         0.99      86
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             20.99     PG  Deleted Scenes,Behind the Scenes
# 2             20.99     PG  Deleted Scenes,Behind the Scenes
# 3             20.99     PG  Deleted Scenes,Behind the Scenes
# 4             20.99     PG  Deleted Scenes,Behind the Scenes
#
#         last_update_x  inventory_id  store_id       last_update_y  rental_id  \
# 0 2006-02-15 05:03:42           1.0       1.0 2006-02-15 05:09:17     4863.0
# 1 2006-02-15 05:03:42           1.0       1.0 2006-02-15 05:09:17     4863.0
# 2 2006-02-15 05:03:42           1.0       1.0 2006-02-15 05:09:17     4863.0
# 3 2006-02-15 05:03:42           1.0       1.0 2006-02-15 05:09:17     4863.0
# 4 2006-02-15 05:03:42           1.0       1.0 2006-02-15 05:09:17     4863.0
#
#           rental_date  customer_id_x         return_date  staff_id_x  \
# 0 2005-07-08 19:03:15          431.0 2005-07-11 21:29:15         2.0
# 1 2005-07-08 19:03:15          431.0 2005-07-11 21:29:15         2.0
# 2 2005-07-08 19:03:15          431.0 2005-07-11 21:29:15         2.0
# 3 2005-07-08 19:03:15          431.0 2005-07-11 21:29:15         2.0
# 4 2005-07-08 19:03:15          431.0 2005-07-11 21:29:15         2.0
#
#         last_update_x  payment_id  customer_id_y  staff_id_y  amount  \
# 0 2006-02-15 21:30:53       11630            431           1    0.99
# 1 2006-02-15 21:30:53       11630            431           1    0.99
# 2 2006-02-15 21:30:53       11630            431           1    0.99
# 3 2006-02-15 21:30:53       11630            431           1    0.99
# 4 2006-02-15 21:30:53       11630            431           1    0.99
#
#          payment_date       last_update_y  category_id       last_update_x  \
# 0 2005-07-08 19:03:15 2006-02-15 22:18:35            6 2006-02-15 05:07:09
# 1 2005-07-08 19:03:15 2006-02-15 22:18:35            6 2006-02-15 05:07:09
# 2 2005-07-08 19:03:15 2006-02-15 22:18:35            6 2006-02-15 05:07:09
# 3 2005-07-08 19:03:15 2006-02-15 22:18:35            6 2006-02-15 05:07:09
# 4 2005-07-08 19:03:15 2006-02-15 22:18:35            6 2006-02-15 05:07:09
#
#         name_x       last_update_y   name_y       last_update_x  actor_id  \
# 0  Documentary 2006-02-15 04:46:27  English 2006-02-15 05:02:19       1.0
# 1  Documentary 2006-02-15 04:46:27  English 2006-02-15 05:02:19      10.0
# 2  Documentary 2006-02-15 04:46:27  English 2006-02-15 05:02:19      20.0
# 3  Documentary 2006-02-15 04:46:27  English 2006-02-15 05:02:19      30.0
# 4  Documentary 2006-02-15 04:46:27  English 2006-02-15 05:02:19      40.0
#
#         last_update_y
# 0 2006-02-15 05:05:03
# 1 2006-02-15 05:05:03
# 2 2006-02-15 05:05:03
# 3 2006-02-15 05:05:03
# 4 2006-02-15 05:05:03

# %%
df.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'original_language_id', 'rental_duration', 'rental_rate', 'length',
#        'replacement_cost', 'rating', 'special_features', 'last_update_x',
#        'inventory_id', 'store_id', 'last_update_y', 'rental_id', 'rental_date',
#        'customer_id_x', 'return_date', 'staff_id_x', 'last_update_x',
#        'payment_id', 'customer_id_y', 'staff_id_y', 'amount', 'payment_date',
#        'last_update_y', 'category_id', 'last_update_x', 'name_x',
#        'last_update_y', 'name_y', 'last_update_x', 'actor_id',
#        'last_update_y'],
#       dtype='object')

# %% [markdown]
# #### observando periodo de los datos

# %%
#Check dates
df["rental_date"].describe()
# Out:
# <ipython-input-21-960fc6004a56>:2: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
# count                   88020
# unique                  15815
# top       2006-02-14 15:16:03
# freq                      999
# first     2005-05-24 22:53:30
# last      2006-02-14 15:16:03
# Name: rental_date, dtype: object

# %% [markdown]
# **Se decide agrupar semanalmente**

# %% [markdown]
# ### Agrupación

# %%
df_complete = df.groupby(['title','film_id', pd.Grouper(key='rental_date', freq='W-MON'),#group by these
           'description', 'release_year','length','rating', 'special_features', #preserve these
            'name_y','name_x',
            'replacement_cost', 'rental_duration', 'rental_rate'],
          )\
        .aggregate(
            {
                'rental_id':'nunique', 'amount':'mean', 'store_id':'nunique', 'actor_id':'nunique'}
        )\
        .reset_index()\
        .rename(
            columns = {'name_y':'language', 'name_x':'category',
                       'rental_id':'rental_count', 'amount':'payment$_mean', 'store_id':'store_count',
                       'actor_id':'actor_count'
                      }
        )\

# %%
df_complete.head()
# Out:
#               title  film_id rental_date  \
# 0  ACADEMY DINOSAUR        1  2005-05-30
# 1  ACADEMY DINOSAUR        1  2005-06-20
# 2  ACADEMY DINOSAUR        1  2005-06-27
# 3  ACADEMY DINOSAUR        1  2005-07-11
# 4  ACADEMY DINOSAUR        1  2005-08-01
#
#                                          description  release_year  length  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006      86
# 1  A Epic Drama of a Feminist And a Mad Scientist...          2006      86
# 2  A Epic Drama of a Feminist And a Mad Scientist...          2006      86
# 3  A Epic Drama of a Feminist And a Mad Scientist...          2006      86
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006      86
#
#   rating                  special_features language     category  \
# 0     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 1     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 2     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 3     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 4     PG  Deleted Scenes,Behind the Scenes  English  Documentary
#
#    replacement_cost  rental_duration  rental_rate  rental_count  \
# 0             20.99                6         0.99             2
# 1             20.99                6         0.99             2
# 2             20.99                6         0.99             1
# 3             20.99                6         0.99             4
# 4             20.99                6         0.99             5
#
#    payment$_mean  store_count  actor_count
# 0           1.49            2           10
# 1           0.99            2           10
# 2           1.99            1           10
# 3           0.99            2           10
# 4           1.39            2           10

# %% [markdown]
# **se crean registros para las semanas faltantes (semanas en las que no se rentaron esas películas)**

# %%
rental_date = pd.date_range(min(df_complete.rental_date), max(df_complete.rental_date), freq='W-MON')
title = df_complete['title'].unique()
idx = pd.MultiIndex.from_product((title, rental_date), names=['title', 'rental_date'])

# %%
df_complete = df_complete.set_index(['title', 'rental_date']).reindex(idx, fill_value=0).reset_index()
df_complete
# Out:
#                   title rental_date  film_id  \
# 0      ACADEMY DINOSAUR  2005-05-30        1
# 1      ACADEMY DINOSAUR  2005-06-06        0
# 2      ACADEMY DINOSAUR  2005-06-13        0
# 3      ACADEMY DINOSAUR  2005-06-20        1
# 4      ACADEMY DINOSAUR  2005-06-27        1
# ...                 ...         ...      ...
# 37357         ZORRO ARK  2006-01-23        0
# 37358         ZORRO ARK  2006-01-30        0
# 37359         ZORRO ARK  2006-02-06        0
# 37360         ZORRO ARK  2006-02-13        0
# 37361         ZORRO ARK  2006-02-20        0
#
#                                              description  release_year  \
# 0      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1                                                      0             0
# 2                                                      0             0
# 3      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 4      A Epic Drama of a Feminist And a Mad Scientist...          2006
# ...                                                  ...           ...
# 37357                                                  0             0
# 37358                                                  0             0
# 37359                                                  0             0
# 37360                                                  0             0
# 37361                                                  0             0
#
#        length rating                  special_features language     category  \
# 0          86     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 1           0      0                                 0        0            0
# 2           0      0                                 0        0            0
# 3          86     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# 4          86     PG  Deleted Scenes,Behind the Scenes  English  Documentary
# ...       ...    ...                               ...      ...          ...
# 37357       0      0                                 0        0            0
# 37358       0      0                                 0        0            0
# 37359       0      0                                 0        0            0
# 37360       0      0                                 0        0            0
# 37361       0      0                                 0        0            0
#
#        replacement_cost  rental_duration  rental_rate  rental_count  \
# 0                 20.99                6         0.99             2
# 1                  0.00                0         0.00             0
# 2                  0.00                0         0.00             0
# 3                 20.99                6         0.99             2
# 4                 20.99                6         0.99             1
# ...                 ...              ...          ...           ...
# 37357              0.00                0         0.00             0
# 37358              0.00                0         0.00             0
# 37359              0.00                0         0.00             0
# 37360              0.00                0         0.00             0
# 37361              0.00                0         0.00             0
#
#        payment$_mean  store_count  actor_count
# 0               1.49            2           10
# 1               0.00            0            0
# 2               0.00            0            0
# 3               0.99            2           10
# 4               1.99            1           10
# ...              ...          ...          ...
# 37357           0.00            0            0
# 37358           0.00            0            0
# 37359           0.00            0            0
# 37360           0.00            0            0
# 37361           0.00            0            0
#
# [37362 rows x 17 columns]

# %% [markdown]
# **Se rellenan las filas vacías**
# dejando los valores de rental_count en 0

# %%
for index, row in df_complete.iterrows():
    if row['film_id'] == 0:
        aux1 = df_complete[df_complete['title'] == row['title']]
        aux2 = aux1[aux1['film_id'] != 0].head(1).reset_index(drop=True)
        df_complete.loc[index,:] = aux2.loc[0,:].values
        df_complete.loc[[index],['rental_date']] = row['rental_date']
        df_complete.loc[[index],['rental_count']] = 0

# %%
df_complete
# Out:
#                   title rental_date  film_id  \
# 0      ACADEMY DINOSAUR  2005-05-30        1
# 1      ACADEMY DINOSAUR  2005-06-06        1
# 2      ACADEMY DINOSAUR  2005-06-13        1
# 3      ACADEMY DINOSAUR  2005-06-20        1
# 4      ACADEMY DINOSAUR  2005-06-27        1
# ...                 ...         ...      ...
# 37357         ZORRO ARK  2006-01-23     1000
# 37358         ZORRO ARK  2006-01-30     1000
# 37359         ZORRO ARK  2006-02-06     1000
# 37360         ZORRO ARK  2006-02-13     1000
# 37361         ZORRO ARK  2006-02-20     1000
#
#                                              description  release_year  \
# 0      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 2      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 3      A Epic Drama of a Feminist And a Mad Scientist...          2006
# 4      A Epic Drama of a Feminist And a Mad Scientist...          2006
# ...                                                  ...           ...
# 37357  A Intrepid Panorama of a Mad Scientist And a B...          2006
# 37358  A Intrepid Panorama of a Mad Scientist And a B...          2006
# 37359  A Intrepid Panorama of a Mad Scientist And a B...          2006
# 37360  A Intrepid Panorama of a Mad Scientist And a B...          2006
# 37361  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#        length rating                         special_features language  \
# 0          86     PG         Deleted Scenes,Behind the Scenes  English
# 1          86     PG         Deleted Scenes,Behind the Scenes  English
# 2          86     PG         Deleted Scenes,Behind the Scenes  English
# 3          86     PG         Deleted Scenes,Behind the Scenes  English
# 4          86     PG         Deleted Scenes,Behind the Scenes  English
# ...       ...    ...                                      ...      ...
# 37357      50  NC-17  Trailers,Commentaries,Behind the Scenes  English
# 37358      50  NC-17  Trailers,Commentaries,Behind the Scenes  English
# 37359      50  NC-17  Trailers,Commentaries,Behind the Scenes  English
# 37360      50  NC-17  Trailers,Commentaries,Behind the Scenes  English
# 37361      50  NC-17  Trailers,Commentaries,Behind the Scenes  English
#
#           category  replacement_cost  rental_duration  rental_rate  \
# 0      Documentary             20.99                6         0.99
# 1      Documentary             20.99                6         0.99
# 2      Documentary             20.99                6         0.99
# 3      Documentary             20.99                6         0.99
# 4      Documentary             20.99                6         0.99
# ...            ...               ...              ...          ...
# 37357       Comedy             18.99                3         4.99
# 37358       Comedy             18.99                3         4.99
# 37359       Comedy             18.99                3         4.99
# 37360       Comedy             18.99                3         4.99
# 37361       Comedy             18.99                3         4.99
#
#        rental_count  payment$_mean  store_count  actor_count
# 0                 2           1.49            2           10
# 1                 0           1.49            2           10
# 2                 0           1.49            2           10
# 3                 2           0.99            2           10
# 4                 1           1.99            1           10
# ...             ...            ...          ...          ...
# 37357             0           4.99            1            3
# 37358             0           4.99            1            3
# 37359             0           4.99            1            3
# 37360             0           4.99            1            3
# 37361             0           4.99            1            3
#
# [37362 rows x 17 columns]

# %%
df_complete.to_csv('data.csv', index=False)
